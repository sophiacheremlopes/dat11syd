# %% [markdown]
# # Data Science Course Week 2 - Lesson 2
# # Introduction to Linear Regression

# %% [markdown]
# Regression is the process of learning a mapping from a vector of input data to a quantitative output given a set of observations. For example, coordinates in a room to Wi-Fi signal strength, someone's Body Mass Index to their life expectancy or a stock's performance over the last 5 days to it's value tomorrow.
#
# There are numerous methods for addressing this problem, each with their own set of assumptions and behaviour. Some are ideal for tackling large volumes of data while others provide more informative probabilistic outputs.
#
# In this lab, we'll focus on Linear Regression; a good point of reference for many other regression techniques and still used widely around the world today due to their simplicity and favourable scaling characteristics.

# %% [markdown]
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %% [markdown]
# # Class Workshop

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %% [markdown]
# Here we are using a dataset of chicago house prices. The dataset is made up of houses that sold and several variables that describe the data.

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", index_col=0)

# %%
house_data.head()
# Out:
#                               Address Neighborhood          HouseType   Price  \
# 0   2111 W Division St #5, Chicago IL  Wicker Park              Condo  390000
# 1     1520 W Walton St #2, Chicago IL  Wicker Park              Condo  320500
# 2        2047 W Thomas St, Chicago IL  Wicker Park  Multi-Family Home  620000
# 3  1735 N Paulina St #314, Chicago IL  Wicker Park              Condo  318000
# 4        1634 W Beach Ave, Chicago IL  Wicker Park  Multi-Family Home  477000
#
#    Bath  CrimeIndex  MinutesToLoop  MilesToLake  Age  LotSizeSqft  \
# 0   NaN        2.59              9         3.91    0            0
# 1   NaN        4.10              7         3.02    0            0
# 2   4.0        2.09              9         3.84   94         3049
# 3   NaN        2.40              9         2.90    0            0
# 4   2.0        4.63              9         2.96   31         2614
#
#    HouseSizeSqft  SchoolIndex  EstimatedPrice
# 0              0         36.2        335790.0
# 1              0         91.7        376908.0
# 2           3492         36.2        629300.0
# 3              0         50.0        297330.0
# 4           1840         78.9        463644.0

# %%
# do we have any missing data?
house_data.isnull().sum()
# Out:
# Address             0
# Neighborhood        0
# HouseType           3
# Price               0
# Bath              149
# CrimeIndex          0
# MinutesToLoop       0
# MilesToLake         0
# Age                 0
# LotSizeSqft         0
# HouseSizeSqft       0
# SchoolIndex         0
# EstimatedPrice      0
# dtype: int64

# %%
# Summarise the data
#house_data.describe()
#house_data.describe(include=['object'])
house_data.describe(include='all')
# Out:
#                                   Address Neighborhood HouseType  \
# count                                 219          219       216
# unique                                219            1         5
# top     1728 N Damen Ave #210, Chicago IL  Wicker Park     Condo
# freq                                    1          219       146
# mean                                  NaN          NaN       NaN
# std                                   NaN          NaN       NaN
# min                                   NaN          NaN       NaN
# 25%                                   NaN          NaN       NaN
# 50%                                   NaN          NaN       NaN
# 75%                                   NaN          NaN       NaN
# max                                   NaN          NaN       NaN
#
#                Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count   2.190000e+02  70.000000  219.000000     219.000000   219.000000
# unique           NaN        NaN         NaN            NaN          NaN
# top              NaN        NaN         NaN            NaN          NaN
# freq             NaN        NaN         NaN            NaN          NaN
# mean    4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std     4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min     2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%     3.190000e+05   2.000000    3.940000       8.000000     3.150000
# 50%     3.900000e+05   2.000000    4.930000       9.000000     3.400000
# 75%     5.125000e+05   3.000000    5.580000      10.000000     3.685000
# max     3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#                Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count   219.000000   219.000000     219.000000   219.000000    2.190000e+02
# unique         NaN          NaN            NaN          NaN             NaN
# top            NaN          NaN            NaN          NaN             NaN
# freq           NaN          NaN            NaN          NaN             NaN
# mean     29.424658   873.200913     699.977169    49.197717    4.862191e+05
# std      49.155880  1392.893683    1175.278922    18.554525    3.978582e+05
# min       0.000000     0.000000       0.000000    16.700000    2.883650e+04
# 25%       0.000000     0.000000       0.000000    36.100000    3.074488e+05
# 50%       0.000000     0.000000       0.000000    50.000000    3.919800e+05
# 75%      41.000000  2614.000000    1344.000000    59.500000    5.324750e+05
# max     131.000000  7405.000000    6422.000000    93.900000    3.973508e+06

# %%
# Look for any linear correlations in the data
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# Bath           -0.039220    -0.029979       0.698526    -0.047992
# CrimeIndex     -0.036644    -0.008807       0.070952    -0.100256
# MinutesToLoop  -0.023820    -0.053292      -0.032437    -0.196728
# MilesToLake    -0.047087     0.006240      -0.046517    -0.205966
# Age             1.000000     0.716774       0.645147    -0.029953
# LotSizeSqft     0.716774     1.000000       0.828598    -0.055458
# HouseSizeSqft   0.645147     0.828598       1.000000    -0.023378
# SchoolIndex    -0.029953    -0.055458      -0.023378     1.000000
# EstimatedPrice  0.255628     0.454939       0.471783    -0.073825
#
#                 EstimatedPrice
# Price                 0.983784
# Bath                  0.105632
# CrimeIndex            0.122793
# MinutesToLoop        -0.034185
# MilesToLake          -0.082604
# Age                   0.255628
# LotSizeSqft           0.454939
# HouseSizeSqft         0.471783
# SchoolIndex          -0.073825
# EstimatedPrice        1.000000

# %%
# Plot each variable against each other 
# scroll down past the subplot information
pd.scatter_matrix(house_data, figsize=(30,30))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7584b645f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584baeba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584ab9f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584ad79e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584a82160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584a95dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584ab5588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584a57b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75849ff198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584a696d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f75849be908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75849e0f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584988588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75849af128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584949c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75849712e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584911908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75848ba4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75848cfeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758487a4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f758489cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584844668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758484b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584805898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584823eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75847cea58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75847f60b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758478eb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75847b7128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584749828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f75846f8d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758473be80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75846be518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75846dff98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75846875f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75846aaba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584647898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584670358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584611978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584632f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f75845d90b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584578748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758459ccf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584544358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75845af898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584504ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758452d208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75844cd828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75844f52e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758448ef28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f75844b64a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584457ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75843fd5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758441f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75843c06d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75843e0cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584387828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584390ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584349b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584371198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7584310c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584324278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75842cfdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758427b4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758428e748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584245048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584282908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75842047b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758422c278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75841ce898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f75841eadd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758418db38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75841b55f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584156c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7584101278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758411f358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75840c09e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75840ea048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f758408a5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75840f1e48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7584049e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75840734a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f75840149e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583fba588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583fd90b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583f7b668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583f9dc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583f447b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583f64358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583f07898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7583f24eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583ecf9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583ed6978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583e90cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583e38358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583e57eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583e014a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583e16f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583dc1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7583de3080>]],
#       dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
# - What looks to be affecting house prices from our initial inspection?
# - What is the type of relationship in those variables affecting price?

# %%
# create a fitted model in one line
lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft', data=house_data).fit()

# print the coefficients!
lm.params
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %% [markdown]
# The summary function provided by the statsmodel library presents lots of useful information about the resulting model.
#
# Key items to pay attention to are:
# - R-squared
# - Adj. R-Squared
# - coef (for each variable)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Wed, 28 Feb 2018   Prob (F-statistic):              0.269
# Time:                        08:05:05   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016    9.89e+04    9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803   -2.61e+05    2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187     -66.297     332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 -28995.66*3 + 133*350

# %% [markdown]
# ## Student Excercise

# %% [markdown]
# Now try creating a regression from just the EstimatedPrice

# %%
# check the distribution of Price vs. EstimatedPrice using a scatterplot
import seaborn as sns
sns.set_style("darkgrid")

sns.lmplot(y='Price', x='EstimatedPrice', data=house_data)

# %%
# Let's try just modelling just using the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Wed, 28 Feb 2018   Prob (F-statistic):          6.25e-164
# Time:                        08:52:51   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758   -1.28e+04    1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000       0.965       1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Question:
# Did the model build on just Estimated Price have a better R-Squared value than the prior model built using Bath and HouseSizeSqft?

# %% [markdown]
# ### Predicting Price using the built model

# %% [markdown]
# Now we will find out what the model estimates the price will be for the the minimum and maximium values of EstimatedPrice

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
# these values will be be used in the built model to predict the Price
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
# predict price given two data points and the built model

preds = lm.predict(X_new)
preds
# Out:
# 0    3.090156e+04
# 1    3.933717e+06
# dtype: float64

# %% [markdown]
# Now lets view a line representing the model build off just Estimated Price, over a scatter plot of the data of Price vs. EstimatedPrice.
#
# To produce the line overlay, we will simply plot a straight line between the two predicted points over the scatter plot.

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# %%
# Now, plot a line over the points that uses just the two points
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')
# this code overlays a straight line between the the coordinates created by X_new and preds
plt.plot(X_new, preds, c='red', linewidth=2)

# %% [markdown]
# ### Experiment
# Now try creating new models by selecting different variables or combinations of variables. Can you get a better fit?

# %%
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice + HouseSizeSqft', data=house_data).fit()

# print the coefficients!
lm.params

#lm.summary()
# Out:
# Intercept         2447.995010
# EstimatedPrice       0.994187
# HouseSizeSqft       -3.442297
# dtype: float64

# %% [markdown]
# ## Themepark

# %% [markdown]
# The file **themepark.csv** has some data from a theme park. Children were asked to rate their experience on a scale
# from 0-5. This data was compared against the number of hours they spent in the park.

# %%
# !ls
# Out:
# anscombe.csv		 drinks.csv			    themepark.csv
# chicagohouseprices2.csv  lesson-04-lab-01_Regression.ipynb

# %%
# Create a pandas DataFrame from this data by reading it in using pandas. 
df = pd.read_csv ("themepark.csv")
# It is located in the same directory as this notebook, so you will not need to provide a filepath.
df.describe(include ='all')
df.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
# Hours        27 non-null int64
# Enjoyment    27 non-null int64
# dtypes: int64(2)
# memory usage: 512.0 bytes

# %%
df = pd.read_csv ("themepark.csv")

# %%
df.plot(kind='scatter', x= 'Hours', y= 'Enjoyment')

# %%
# Have a look at the data (e.g. display the head or tail, use describe, etc.)

# %%
# Draw a scatterplot of this data.

# %%
# Try doing a linear regression on this data
lm = smf.ols(formula='Enjoyment ~ Hours', data=df).fit()

# print the coefficients!
lm.params
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Enjoyment   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.660
# Method:                 Least Squares   F-statistic:                     51.47
# Date:                Wed, 28 Feb 2018   Prob (F-statistic):           1.61e-07
# Time:                        09:35:23   Log-Likelihood:                -35.570
# No. Observations:                  27   AIC:                             75.14
# Df Residuals:                      25   BIC:                             77.73
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6631      0.391      1.697      0.102      -0.142       1.468
# Hours          0.9067      0.126      7.174      0.000       0.646       1.167
# ==============================================================================
# Omnibus:                        0.596   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.742   Jarque-Bera (JB):                0.660
# Skew:                           0.138   Prob(JB):                        0.719
# Kurtosis:                       2.285   Cond. No.                         7.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Plot this regression over the top of the data. Could the regression be better?
X_new1 = pd.DataFrame({'Hours': [df.Hours.min(), df.Hours.max()]})
X_new1.head()
# Out:
#    Hours
# 0      1
# 1      5

# %%
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
preds1 = lm.predict(X_new1)
preds1
# Out:
# 0    1.569799
# 1    5.196644
# dtype: float64

# %%
# Now, plot a line over the points that uses just the two points
df.plot(kind='scatter', x= 'Hours', y= 'Enjoyment')
# this code overlays a straight line between the the coordinates created by X_new and preds
plt.plot(X_new1, preds1, c='red', linewidth=2)
